# %%
import pandas

# pandas.options.display.max_columns = None
# pandas.options.display.max_rows = None

dogbite_data = pandas.read_csv("Dog_Bite_Data.csv")

dogbite_data
# Out:
#       Bite Number Bite Type           Incident Date  Victim Age  \
# 0      B17-009452   CONTACT  09/08/2020 07:45:00 AM         NaN
# 1      B17-009452   CONTACT  09/08/2020 07:45:00 AM         NaN
# 2      B17-009452   CONTACT  09/08/2020 07:45:00 AM        50.0
# 3      B18-010201      BITE  02/18/2020 06:00:00 PM         NaN
# 4      B18-011152      BITE  08/04/2020 06:00:00 PM        27.0
# ...           ...       ...                     ...         ...
# 10673  B20-014694      BITE  06/13/2020 08:00:00 PM        70.0
# 10674  B20-014697      BITE  06/13/2020 08:00:00 PM        70.0
# 10675  B20-014695      BITE  06/13/2020 08:00:00 PM        70.0
# 10676  B20-014646      BITE  06/13/2020 08:00:00 PM        70.0
# 10677  B20-014849      BITE  07/25/2020 05:00:00 PM        24.0
#
#       Victim Relationship Bite Location Bite Severity Bite Circumstance  \
# 0                     NaN           NaN           NaN               NaN
# 1                     NaN           NaN           NaN               NaN
# 2                NEIGHBOR        R HAND         MINOR        BITE/SCRAT
# 3                   OWNED         HANDS      PUNCTURE           HUGGING
# 4                   OWNED         R LEG       SCRATCH          FIGHTING
# ...                   ...           ...           ...               ...
# 10673            STRANGER        L HAND      PUNCTURE           FEEDING
# 10674            STRANGER        L HAND      PUNCTURE           FEEDING
# 10675            STRANGER        L HAND      PUNCTURE           FEEDING
# 10676            STRANGER        L HAND      PUNCTURE           FEEDING
# 10677           OWNER/VIC         L ARM      PUNCTURE           WALKING
#
#       Controlled By  Treatment Cost          Date Reported   \
# 0               NaN             0.0  09/09/2017 12:00:00 AM
# 1               NaN             0.0  09/09/2017 12:00:00 AM
# 2               NaN             0.0  09/09/2017 12:00:00 AM
# 3             OWNER             0.0  02/19/2018 12:00:00 AM
# 4             OWNER             NaN  08/05/2018 12:00:00 AM
# ...             ...             ...                     ...
# 10673         OTHER             0.0  06/14/2020 12:00:00 AM
# 10674         OTHER             0.0  06/14/2020 12:00:00 AM
# 10675         OTHER             0.0  06/14/2020 12:00:00 AM
# 10676         OTHER             0.0  06/14/2020 12:00:00 AM
# 10677         OWNER             0.0  07/25/2020 12:00:00 AM
#
#                           Incident Location
# 0         2405 HARTLINE DR ,DALLAS TX 75228
# 1         2405 HARTLINE DR ,DALLAS TX 75228
# 2         2405 HARTLINE DR ,DALLAS TX 75228
# 3        11737 FERNALD AVE ,DALLAS TX 75218
# 4      10178 CASA VIEW AVE ,DALLAS TX 75228
# ...                                     ...
# 10673  3230 SAN MEDINA AVE ,DALLAS TX 75228
# 10674  3230 SAN MEDINA AVE ,DALLAS TX 75228
# 10675  3230 SAN MEDINA AVE ,DALLAS TX 75228
# 10676  3230 SAN MEDINA AVE ,DALLAS TX 75228
# 10677  2502 S MARSALIS AVE ,DALLAS TX 75216
#
# [10678 rows x 12 columns]
